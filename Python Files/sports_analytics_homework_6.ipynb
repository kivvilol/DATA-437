# %%
# 1) The strength of a simple linear regression should not change when units are converted from feet to inches. This is because a change in units
#    will not effect the overall pattern in the data, even if we change units for both x and y variables. 

# 2) C

# 3) D

# 4) The coefficient of determination tells us the strength and direction of our model. Because our value is 97.5%, we can determine that we have 
#    a very strong positive relationship from our model. This also tells us that our slope should be positive because a positive coefficient
#    of determination tells us that our y generally increases as x increases.

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

mlb = pd.read_csv('Teams.csv')
mlb.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
# creating run differential
mlb['RD'] = mlb['R'] - mlb['RA']

# creating win percentage
mlb['Wpct'] = mlb['W'] / (mlb['W'] + mlb['L'])

# %%
# aggregating data
mlb_agg = mlb[['yearID', 'RD', 'Wpct']]
mlb_agg.head()
# Out:
#    yearID   RD      Wpct
# 0    1871   98  0.666667
# 1    1871   61  0.678571
# 2    1871  -92  0.344828
# 3    1871 -106  0.368421
# 4    1871  -11  0.484848

# %%
# selecting when yearID >= 2001
mlb_agg = mlb_agg[mlb_agg['yearID'] >= 2001]
mlb_agg.head()
# Out:
#       yearID   RD      Wpct
# 2355    2001  -39  0.462963
# 2356    2001  141  0.567901
# 2357    2001   86  0.543210
# 2358    2001 -142  0.391304
# 2359    2001   27  0.509317

# %%
# building a simple linear regression model
mlb_ols = smf.ols(formula = 'Wpct ~ RD', data = mlb_agg).fit()

# extracting results
mlb_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Wpct   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     3542.
# Date:                Wed, 27 Oct 2021   Prob (F-statistic):          1.95e-253
# Time:                        11:18:43   Log-Likelihood:                 1289.3
# No. Observations:                 600   AIC:                            -2575.
# Df Residuals:                     598   BIC:                            -2566.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5000      0.001    433.296      0.000       0.498       0.502
# ...

# %%
# new observation data
newdata = pd.DataFrame({'RD' : [87]})

# predicting salary 
mlb_ols.predict(newdata)

## The win percentage when the run differential is equal to 87 is 55%. 

## Our regression model from part (d) is equal to Y = 0.5 + 0.0006x1. Because our coefficients are greater than 2*std error for both variables
## and the overall model, we can determine that the slope of our line is statistically significant.
# Out:
# 0    0.554624
# dtype: float64
